# %%
import numpy as np
import matplotlib.pyplot as mpl

# %% [markdown]
# #### Podpunkt a

# %%
random_uniform = np.random.uniform(0,100, 500)

# %%
print(random_uniform)
# Out:
# [2.06109181e+01 2.47524190e+01 4.97031489e+01 7.18313670e+01
#  1.81053752e+01 5.89603496e+01 4.11224822e+01 3.89534619e+01
#  4.87013980e+00 8.31678177e+01 6.33230515e+00 2.36909876e+00
#  2.12365639e+01 6.90991221e+01 2.86958242e+01 3.85402235e+01
#  3.51928222e+01 5.84993653e+01 4.30222001e+01 7.71016043e+01
#  5.97563652e+01 8.24636356e+01 8.65546902e+01 7.37180760e+01
#  2.43086165e+00 1.81678081e+01 8.52864429e+01 1.25432462e+01
#  8.44423146e+01 9.41464960e+01 1.39149857e+01 7.85343046e+01
#  4.23120462e+01 5.26466100e+01 9.18976818e+00 4.19487883e+01
#  2.01270613e+01 4.79980526e+01 4.05113407e+00 1.67715654e+01
#  7.49589638e+01 8.58405165e+01 4.41753781e+01 5.05678080e+01
#  8.65432150e+01 3.12980445e+00 7.46022177e+01 1.47702082e+01
#  8.65096020e+01 4.91065927e+01 8.16703326e+01 6.13120742e+01
#  6.87162856e+01 3.51235890e+01 6.65287016e+01 5.12359389e+01
#  8.52839284e+01 9.89170557e+01 2.85815862e+01 4.78395712e+01
# ...

# %% [markdown]
# #### Podpunkt b

# %%
mpl.plot(random_uniform)

# %%
mpl.scatter(range(0, len(random_uniform)), random_uniform)

# %% [markdown]
# #### Podpunkt c
# Histogram (bin=25)
# matplotlib.pyplot.hist
# The bins, range, density, and weights parameters are forwarded to numpy.histogram.
#
# #### TODO To add scale, chart description, legend. Please think about readability

# %%
counts, bins = np.histogram(random_uniform)
mpl.stairs(counts, bins)

# %%
mpl.hist(bins[:15], bins, weights=counts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 mpl.hist(bins[:15], bins, weights=counts)
#
# File ~/Workspaces/university/python-exercises/venv/lib/python3.9/site-packages/matplotlib/pyplot.py:3236, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3211 @_copy_docstring_and_deprecators(Axes.hist)
#    3212 def hist(
#    3213     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3234     BarContainer | Polygon | list[BarContainer | Polygon],
#    3235 ]:
# -> 3236     return gca().hist(
#    3237         x,
#    3238         bins=bins,
#    3239         range=range,
#    3240         density=density,
#    3241         weights=weights,
#    3242         cumulative=cumulative,
#    3243         bottom=bottom,
#    3244         histtype=histtype,
# ...
